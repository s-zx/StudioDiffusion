# %% [markdown]
# # 01 Data Exploration
#
# Explore ABO and platform-curated image sets. Visualize CLIP embedding distributions per platform.

# %%
# TODO: load platform_sets, compute CLIP embeddings, TSNE/UMAP visualization
