# %% [markdown]
# # 02 Segmentation Evaluation
#
# Compare SAM2 vs U²Net on DeepFashion2 ground-truth masks.

# %%
# TODO: run segmentation/evaluate_masks.py on SAM2 and U2Net, plot IoU distributions
